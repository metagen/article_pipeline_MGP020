# %%
import pandas as pd

# %%
nm_all = pd.read_csv("../data_input/nm.all.tsv", sep="\t", header=0, index_col=0)

# %%
nm1 = nm_all.dropna()

# %%
nm1
# Out:
#         S004_0w    S004_2w    S004_4w    S009_0w    S009_2w    S009_4w  \
# IgA    0.350628   0.658890   0.029820   2.571948   7.115209   1.727435
# 量      1.406250   1.208333   1.428571   0.700000   0.966667   1.285714
# 性状     2.187500   2.666667   3.071429   2.500000   2.400000   3.714286
# 色      4.625000   4.833333   4.142857   5.000000   4.466667   3.857143
# におい    2.687500   2.916667   3.000000   3.300000   3.266667   3.357143
# 残便感    2.062500   2.833333   2.357143   2.700000   2.933333   2.714286
# 痛み     4.000000   3.916667   4.000000   2.600000   2.400000   2.785714
# 排便回数   1.142857   0.857143   1.000000   0.714286   1.071429   1.000000
# 排便日数  14.000000  12.000000  14.000000  10.000000  10.000000  11.000000
#
#        S013_0w   S013_2w    S013_4w    S021_0w  ...    S130_4w   S131_0w  \
# IgA   0.918806  0.675650   1.444846   3.085240  ...   0.003886  0.482978
# 量     1.722222  2.000000   1.964286   4.571429  ...   1.333333  2.000000
# ...

# %%
nm_all.isna()
# Out:
#                       S004_0w  S004_2w  S004_4w  S009_0w  S009_2w  S009_4w  \
# body_weight             False     True    False    False     True    False
# water_content           False     True    False    False     True    False
# protein_content         False     True    False    False     True    False
# mineral_content         False     True    False    False     True    False
# somatic_fat_volume      False     True    False    False     True    False
# muscle_mass             False     True    False    False     True    False
# skeletal_muscle_mass    False     True    False    False     True    False
# BMI                     False     True    False    False     True    False
# somatic_fat_rate        False     True    False    False     True    False
# InBody Score            False     True    False    False     True    False
# basal_metabolic_rate    False     True    False    False     True    False
# ...
