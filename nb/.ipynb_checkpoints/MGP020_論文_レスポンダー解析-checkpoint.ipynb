# %%
import os
import sys
import warnings
import numpy as np
import pandas as pd
import scipy.stats as st
import seaborn as sns
import matplotlib.pyplot as plt
from sigfig import round
from collections import defaultdict
from os.path import dirname, abspath
from IPython.display import display

# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
def get_samesubject_sampleids(mdf, mkey, mvals, msk="subject_id", axis=1, return_subjectid=False):
    def query_col(df, key, val):
        return df.loc[:, df.loc[key, :] == val]

    m = "metadata table is not unique by -mk and -msk"
    subject_ids = sorted(set(mdf.loc[msk, :]))
    sample_ids = []
    for mval in mvals:
        _sample_ids = []
        for subject_id in subject_ids:
            mdf_ext_step1 = query_col(mdf, msk, subject_id)
            mdf_ext_step2 = query_col(mdf_ext_step1, mkey, mval)
            if mdf_ext_step2.shape[1] != 1:
                raise ValueError(m)
            _sample_ids.append(mdf_ext_step2.columns[0])
        sample_ids.append(_sample_ids)

    if return_subjectid and axis == 1:
        return sample_ids, subject_ids
    elif not return_subjectid and axis == 1:
        return sample_ids
    elif return_subjectid and axis == 0:
        return [list(x) for x in zip(*sample_ids)], subject_ids
    elif not return_subjectid and axis == 0:
        return [list(x) for x in zip(*sample_ids)]


def make_effsize_df(df, mdf, mkey, mvals, pattern_responder_score):
    (sampleids_ctrl, sampleids_test), subject_ids = get_samesubject_sampleids(mdf, mkey, mvals, return_subjectid=True)
    dd = defaultdict(lambda: defaultdict(int))
    for ind in df.index:
        for sampleid_ctrl, sampleid_test, subject_id in zip(sampleids_ctrl, sampleids_test, subject_ids):
            ctrl = df.loc[ind, sampleid_ctrl]
            test = df.loc[ind, sampleid_test]
            if pattern_responder_score == 1:
                effsize = test - ctrl
            elif pattern_responder_score == 2:
                effsize = (test - ctrl) / ctrl
            else:
                raise ValueError()
            dd[subject_id][ind] = effsize
    return pd.DataFrame(dd)


def fill_inf(s):
    if s.isnull().any():
        raise ValueError("isnull.any")
    s = s.replace(np.inf, np.nan)
    s = s.fillna(s.max())
    s = s.replace(-np.inf, np.nan)
    s = s.fillna(s.min())
    return s


def dropna_paired(vals1, vals2):
    new_vals1 = []
    new_vals2 = []
    for val1, val2 in zip(vals1, vals2):
        if not np.isnan(val1) and not np.isnan(val2):
            new_vals1.append(val1)
            new_vals2.append(val2)
    return new_vals1, new_vals2

# %%
ge = pd.read_csv("../data_input/ge.tsv", sep="\t", header=0, index_col=0)
ra = pd.read_csv("../data_input/ra.tsv", sep="\t", header=0, index_col=0)
co = pd.read_csv("../data_input/scfa.abs.tsv", sep="\t", header=0, index_col=0)
nm = pd.read_csv("../data_input/nm.tsv", sep="\t", header=0, index_col=0)
me = pd.read_csv("../data_input/me.tsv", sep="\t", header=0, index_col=0)

ge = ge.loc[ge.mean(axis=1) >= 0.001]
ra = ra.loc[((ra > 0).sum(axis=1) / len(ra.columns)) >= 0.25]
ra.drop(ra.loc[ra.index.str.contains("\n")].index, inplace=True)
ra.drop(ra.loc[ra.index.str.startswith("XA")].index, inplace=True)
ra.drop(ra.loc[ra.index.str.startswith("XC")].index, inplace=True)

# %%
def make_responder_table(mkey, mvals, ge, ra, nm, me, dk, group):
    ge_GP = ge.loc[:, me.loc["group"]==group]
    ra_GP = ra.loc[:, me.loc["group"]==group]
    nm_GP = nm.loc[:, me.loc["group"]==group]
    me_GP = me.loc[:, me.loc["group"]==group]    

    pattern_responder_score = 2

    ge_eff = make_effsize_df(ge_GP, me_GP, mkey, mvals, pattern_responder_score).fillna(0)
    ra_eff = make_effsize_df(ra_GP, me_GP, mkey, mvals, pattern_responder_score).fillna(0)
    nm_eff = make_effsize_df(nm_GP, me_GP, mkey, mvals, pattern_responder_score).fillna(0)

    eff_all = pd.concat([ge_eff, ra_eff, nm_eff])

    me_base = me_GP.T.query(f"timepoint == '0w'").T
    me_eff = me_base.copy()
    me_eff.columns = me_eff.loc["subject_id", :]

    # baselineの抽出
    ge_base = ge_GP.loc[:, me_base.columns]
    ra_base = ra_GP.loc[:, me_base.columns]
    nm_base = nm_GP.loc[:, me_base.columns]

    # ベースライン
    dd = defaultdict(lambda: defaultdict(int))
    base = pd.concat([ge_base, ra_base, nm_base]).T
    _base = base.copy()
    _base.index = [me_GP.loc["subject_id", sample_id] for sample_id in _base.index]
    for col in _base.columns:
        x = _base.loc[_base.index, col]
        y = eff_all.loc[dk, _base.index]
        x = fill_inf(x)
        y = fill_inf(y)
        per, pep = st.pearsonr(x, y)
        spr, spp = st.spearmanr(x, y)
        dd[col]["PearsonR_base"] = per
        dd[col]["PearsonP_base"] = pep
        dd[col]["SpearmanR_base"] = spr
        dd[col]["SpearmanP_base"] = spp
    responder_base_GP = pd.DataFrame(dd).T

    # 変化量
    dd = defaultdict(lambda: defaultdict(int))
    eff = eff_all.T
    for col in eff.columns:
        x = eff[col]
        y = eff[dk]
        x = fill_inf(x)
        y = fill_inf(y)
        per, pep = st.pearsonr(x, y)
        spr, spp = st.spearmanr(x, y)
        dd[col]["PearsonR_eff"] = per
        dd[col]["PearsonP_eff"] = pep
        dd[col]["SpearmanR_eff"] = spr
        dd[col]["SpearmanP_eff"] = spp
    responder_eff_GP = pd.DataFrame(dd).T
    
    return responder_base_GP, responder_eff_GP

# %%
resp_IgA_C_base, resp_IgA_C_eff = make_responder_table("timepoint", ["0w", "4w"], ge, ra, nm, me,"IgA", "C")
resp_IgA_T_base, resp_IgA_T_eff = make_responder_table("timepoint", ["0w", "4w"], ge, ra, nm, me,"IgA", "T")
resp_Acetate_C_base, resp_Acetate_C_eff = make_responder_table("timepoint", ["0w", "4w"], ge, co, nm, me,"Acetate", "C")
resp_Acetate_T_base, resp_Acetate_T_eff = make_responder_table("timepoint", ["0w", "4w"], ge, co, nm, me,"Acetate", "T")
resp_Propionate_C_base, resp_Propionate_C_eff = make_responder_table("timepoint", ["0w", "4w"], ge, ra, nm, me,"Propionic acid", "C")
resp_Propionate_T_base, resp_Propionate_T_eff = make_responder_table("timepoint", ["0w", "4w"], ge, ra, nm, me,"Propionic acid", "T")
resp_Butyrate_C_base, resp_Butyrate_C_eff = make_responder_table("timepoint", ["0w", "4w"], ge, ra, nm, me,"Butyric acid", "C")
resp_Butyrate_T_base, resp_Butyrate_T_eff = make_responder_table("timepoint", ["0w", "4w"], ge, ra, nm, me,"Butyric acid", "T")
resp_Succinate_C_base, resp_Succinate_C_eff = make_responder_table("timepoint", ["0w", "4w"], ge, ra, nm, me,"Succinic acid", "C")
resp_Succinate_T_base, resp_Succinate_T_eff = make_responder_table("timepoint", ["0w", "4w"], ge, ra, nm, me,"Succinic acid", "T")

# %%
# !mkdir -p ../data_output/responder

# %%
resp_IgA_C_base.to_csv("../data_output/responder/responder.IgA_C_base.tsv", sep="\t")
resp_IgA_C_eff.to_csv("../data_output/responder/responder.IgA_C_eff.tsv", sep="\t")
resp_IgA_T_base.to_csv("../data_output/responder/responder.IgA_T_base.tsv", sep="\t")
resp_IgA_T_eff.to_csv("../data_output/responder/responder.IgA_T_eff.tsv", sep="\t")
resp_Acetate_C_base.to_csv("../data_output/responder/responder.Acetate_C_base.tsv", sep="\t")
resp_Acetate_C_eff.to_csv("../data_output/responder/responder.Acetate_C_eff.tsv", sep="\t")
resp_Acetate_T_base.to_csv("../data_output/responder/responder.Acetate_T_base.tsv", sep="\t")
resp_Acetate_T_eff.to_csv("../data_output/responder/responder.Acetate_T_eff.tsv", sep="\t")
resp_Propionate_C_base.to_csv("../data_output/responder/responder.Propionate_C_base.tsv", sep="\t")
resp_Propionate_C_eff.to_csv("../data_output/responder/responder.Propionate_C_eff.tsv", sep="\t")
resp_Propionate_T_base.to_csv("../data_output/responder/responder.Propionate_T_base.tsv", sep="\t")
resp_Propionate_T_eff.to_csv("../data_output/responder/responder.Propionate_T_eff.tsv", sep="\t")
resp_Butyrate_C_base.to_csv("../data_output/responder/responder.Butyrate_C_base.tsv", sep="\t")
resp_Butyrate_C_eff.to_csv("../data_output/responder/responder.Butyrate_C_eff.tsv", sep="\t")
resp_Butyrate_T_base.to_csv("../data_output/responder/responder.Butyrate_T_base.tsv", sep="\t")
resp_Butyrate_T_eff.to_csv("../data_output/responder/responder.Butyrate_T_eff.tsv", sep="\t")
resp_Succinate_C_base.to_csv("../data_output/responder/responder.Succinate_C_base.tsv", sep="\t")
resp_Succinate_C_eff.to_csv("../data_output/responder/responder.Succinate_C_eff.tsv", sep="\t")
resp_Succinate_T_base.to_csv("../data_output/responder/responder.Succinate_T_base.tsv", sep="\t")
resp_Succinate_T_eff.to_csv("../data_output/responder/responder.Succinate_T_eff.tsv", sep="\t")

# %%
display(resp_IgA_C_base.head())
display(resp_IgA_C_eff.head())
display(resp_IgA_T_base.head())
display(resp_IgA_T_eff.head())
display(resp_Propionate_C_base.head())
display(resp_Propionate_C_eff.head())
display(resp_Propionate_T_base.head())
display(resp_Propionate_T_eff.head())
display(resp_Butyrate_C_base.head())
display(resp_Butyrate_C_eff.head())
display(resp_Butyrate_T_base.head())
display(resp_Butyrate_T_eff.head())
# Out:
#                   PearsonR_base  PearsonP_base  SpearmanR_base  SpearmanP_base
# Bacteroides           -0.061149       0.731191        0.179526        0.309659
# Bifidobacterium        0.112242       0.527387        0.200611        0.255283
# Blautia               -0.185632       0.293215       -0.051188        0.773730
# Faecalibacterium      -0.042739       0.810332        0.031933        0.857718
# Prevotella 9           0.236826       0.177483       -0.281251        0.107106
#                   PearsonR_eff  PearsonP_eff  SpearmanR_eff  SpearmanP_eff
# Bacteroides           0.090218      0.611863       0.133079       0.453076
# Bifidobacterium      -0.133356      0.452127      -0.054240       0.760622
# Blautia               0.189803      0.282310       0.119022       0.502576
# Faecalibacterium     -0.084548      0.634497       0.082665       0.642087
# Prevotella 9          0.009758      0.956321      -0.133840       0.450472
#                   PearsonR_base  PearsonP_base  SpearmanR_base  SpearmanP_base
# Bacteroides           -0.266357       0.134049        0.076537        0.672045
# Bifidobacterium        0.165860       0.356285        0.424835        0.013724
# Blautia                0.185616       0.301048        0.069853        0.699293
# Faecalibacterium      -0.108631       0.547333        0.062348        0.730328
# Prevotella 9          -0.093848       0.603427       -0.413318        0.016812
#                   PearsonR_eff  PearsonP_eff  SpearmanR_eff  SpearmanP_eff
# Bacteroides           0.182284      0.309961       0.299465       0.090442
# Bifidobacterium      -0.093947      0.603045      -0.125345       0.487033
# Blautia              -0.091337      0.613193      -0.090575       0.616172
# Faecalibacterium      0.169955      0.344364      -0.267515       0.132302
# Prevotella 9          0.009605      0.957691       0.271491       0.126430
#                   PearsonR_base  PearsonP_base  SpearmanR_base  SpearmanP_base
# Bacteroides            0.091558       0.606564        0.131551        0.458326
# Bifidobacterium       -0.185988       0.292274       -0.094270        0.595898
# Blautia                0.047014       0.791759        0.159218        0.368428
# Faecalibacterium      -0.062001       0.727585        0.043545        0.806824
# Prevotella 9          -0.182219       0.302336       -0.156342        0.377252
#                   PearsonR_eff  PearsonP_eff  SpearmanR_eff  SpearmanP_eff
# Bacteroides          -0.359429      0.036819      -0.349121       0.042996
# Bifidobacterium       0.237024      0.177110       0.193583       0.272655
# Blautia              -0.098190      0.580630      -0.123300       0.487228
# Faecalibacterium      0.231408      0.187901       0.194820       0.269542
# Prevotella 9          0.146289      0.409057       0.159427       0.367791
#                   PearsonR_base  PearsonP_base  SpearmanR_base  SpearmanP_base
# Bacteroides            0.090940       0.614746       -0.027406        0.879664
# Bifidobacterium       -0.219225       0.220285       -0.228796        0.200291
# Blautia                0.280091       0.114394        0.289104        0.102722
# Faecalibacterium      -0.134089       0.456907        0.116484        0.518569
# Prevotella 9          -0.161306       0.369829       -0.004519        0.980086
#                   PearsonR_eff  PearsonP_eff  SpearmanR_eff  SpearmanP_eff
# Bacteroides          -0.198558      0.267981      -0.074532       0.680179
# Bifidobacterium      -0.140414      0.435750      -0.279936       0.114603
# Blautia              -0.258919      0.145677      -0.344251       0.049792
# Faecalibacterium     -0.055883      0.757408      -0.023269       0.897725
# Prevotella 9          0.647043      0.000047       0.502348       0.002891
#                   PearsonR_base  PearsonP_base  SpearmanR_base  SpearmanP_base
# Bacteroides            0.112255       0.527338        0.180749        0.306321
# Bifidobacterium       -0.254755       0.145942       -0.211612        0.229592
# Blautia                0.129380       0.465841        0.023837        0.893552
# Faecalibacterium      -0.149149       0.399860       -0.191444        0.278092
# Prevotella 9          -0.075963       0.669389       -0.010888        0.951266
#                   PearsonR_eff  PearsonP_eff  SpearmanR_eff  SpearmanP_eff
# Bacteroides          -0.314449      0.070108      -0.276700       0.113152
# Bifidobacterium       0.148543      0.401799       0.272727       0.118636
# Blautia              -0.113072      0.524319      -0.130940       0.460435
# Faecalibacterium      0.231561      0.187600       0.336619       0.051580
# Prevotella 9          0.052112      0.769753      -0.020666       0.907645
#                   PearsonR_base  PearsonP_base  SpearmanR_base  SpearmanP_base
# Bacteroides            0.070795       0.695432        0.039439        0.827502
# Bifidobacterium       -0.256528       0.149566       -0.159940        0.373949
# Blautia                0.286605       0.105864        0.345588        0.048853
# Faecalibacterium      -0.260598       0.142990       -0.249058        0.162202
# Prevotella 9          -0.249539       0.161367       -0.103535        0.566391
#                   PearsonR_eff  PearsonP_eff  SpearmanR_eff  SpearmanP_eff
# Bacteroides          -0.356941      0.041437      -0.385027       0.026924
# Bifidobacterium      -0.057979      0.748596      -0.204730       0.253084
# Blautia              -0.155530      0.387434      -0.283422       0.109970
# Faecalibacterium      0.039606      0.826779       0.039340       0.827925
# Prevotella 9          0.601165      0.000216       0.393194       0.023594

# %%
def draw_heatmap(df_base_C, df_base_T, df_eff_C, df_eff_T, ref, dk):
    responder_eff = pd.DataFrame(columns=["CF_R", "CF_p", "FG_R", "FG_p"])

    for ind in ref.index:
        if ind == dk:
            continue
    #     if (responder_eff_C.loc[ind, "SpearmanP_eff"] < 0.05) or (responder_eff_T.loc[ind, "SpearmanP_eff"] < 0.05):
        if ((df_eff_C.loc[ind, "PearsonP_eff"] < 0.1) and (df_eff_C.loc[ind, "SpearmanP_eff"] < 0.05)) or ((df_eff_T.loc[ind, "PearsonP_eff"] < 0.1) and (df_eff_T.loc[ind, "SpearmanP_eff"] < 0.05)):
            responder_eff.loc[ind, "CF_R"] = resp_IgA_C_eff.loc[ind, "SpearmanR_eff"]
            responder_eff.loc[ind, "CF_p"] = resp_IgA_C_eff.loc[ind, "SpearmanP_eff"]
            responder_eff.loc[ind, "FG_R"] = resp_IgA_T_eff.loc[ind, "SpearmanR_eff"]
            responder_eff.loc[ind, "FG_p"] = resp_IgA_T_eff.loc[ind, "SpearmanP_eff"]

    responder_base = pd.DataFrame(columns=["CF_R", "CF_p", "FG_R", "FG_p"])

    for ind in ref.index:
        if ind == dk:
            continue
    #     if (responder_base_C.loc[ind, "SpearmanP_base"] < 0.05) or (responder_base_T.loc[ind, "SpearmanP_base"] < 0.05):
        if ((df_base_C.loc[ind, "PearsonP_base"] < 0.1) and (df_base_C.loc[ind, "SpearmanP_base"] < 0.05)) or ((df_base_T.loc[ind, "PearsonP_base"] < 0.1) and (df_base_T.loc[ind, "SpearmanP_base"] < 0.05)):
            responder_base.loc[ind, "CF_R"] = resp_IgA_C_base.loc[ind, "SpearmanR_base"]
            responder_base.loc[ind, "CF_p"] = resp_IgA_C_base.loc[ind, "SpearmanP_base"]
            responder_base.loc[ind, "FG_R"] = resp_IgA_T_base.loc[ind, "SpearmanR_base"]
            responder_base.loc[ind, "FG_p"] = resp_IgA_T_base.loc[ind, "SpearmanP_base"]
            
    plt.figure(figsize=(3, 1*len(responder_base.index)))
    sns.heatmap(responder_base[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
    plt.savefig(f"heatmap.responder.{dk}.baseline.pdf", bbox_inches="tight")
    plt.show()
    
    plt.figure(figsize=(3, 1*len(responder_eff.index)))
    sns.heatmap(responder_eff[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
    plt.savefig(f"heatmap.responder.{dk}.eff.pdf", bbox_inches="tight")
    plt.show()

# %%
plt.rcParams["font.family"] = "Arial"

# %%
draw_heatmap(resp_IgA_C_base, resp_IgA_T_base, resp_IgA_C_eff, resp_IgA_T_eff, "IgA")
draw_heatmap(resp_Propionate_C_base, resp_Propionate_T_base, resp_Propionate_C_eff, resp_Propionate_T_eff, "Propionic acid")
draw_heatmap(resp_Butyrate_C_base, resp_Butyrate_T_base, resp_Butyrate_C_eff, resp_Butyrate_T_eff, "Butyric acid")

# %%
plt.figure(figsize=(3, 1*len(responder_base.index)))
sns.heatmap(responder_base[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
plt.savefig("heatmap.responder.baseline.pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(3, 1*len(responder_eff.index)))
sns.heatmap(responder_eff[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
plt.savefig("heatmap.responder.eff.pdf", bbox_inches="tight")
plt.show()

# %%
responder_eff = pd.DataFrame(columns=["CF_R", "CF_p", "FG_R", "FG_p"])

for ind in ge_eff.index:
#     if (resp_Propionate_C_eff.loc[ind, "SpearmanP_eff"] < 0.05) or (resp_Propionate_T_eff.loc[ind, "SpearmanP_eff"] < 0.05):
    if ((resp_Propionate_C_eff.loc[ind, "PearsonP_eff"] < 0.1) and (resp_Propionate_C_eff.loc[ind, "SpearmanP_eff"] < 0.05)) or ((resp_Propionate_T_eff.loc[ind, "PearsonP_eff"] < 0.1) and (resp_Propionate_T_eff.loc[ind, "SpearmanP_eff"] < 0.05)):
        responder_eff.loc[ind, "CF_R"] = resp_Propionate_C_eff.loc[ind, "SpearmanR_eff"]
        responder_eff.loc[ind, "CF_p"] = resp_Propionate_C_eff.loc[ind, "SpearmanP_eff"]
        responder_eff.loc[ind, "FG_R"] = resp_Propionate_T_eff.loc[ind, "SpearmanR_eff"]
        responder_eff.loc[ind, "FG_p"] = resp_Propionate_T_eff.loc[ind, "SpearmanP_eff"]

# %%
responder_base = pd.DataFrame(columns=["CF_R", "CF_p", "FG_R", "FG_p"])

for ind in ge_base.index:
#     if (resp_Propionate_C_base.loc[ind, "SpearmanP_base"] < 0.05) or (resp_Propionate_T_base.loc[ind, "SpearmanP_base"] < 0.05):
    if ((resp_Propionate_C_base.loc[ind, "PearsonP_base"] < 0.1) and (resp_Propionate_C_base.loc[ind, "SpearmanP_base"] < 0.05)) or ((resp_Propionate_T_base.loc[ind, "PearsonP_base"] < 0.1) and (resp_Propionate_T_base.loc[ind, "SpearmanP_base"] < 0.05)):
        responder_base.loc[ind, "CF_R"] = resp_Propionate_C_base.loc[ind, "SpearmanR_base"]
        responder_base.loc[ind, "CF_p"] = resp_Propionate_C_base.loc[ind, "SpearmanP_base"]
        responder_base.loc[ind, "FG_R"] = resp_Propionate_T_base.loc[ind, "SpearmanR_base"]
        responder_base.loc[ind, "FG_p"] = resp_Propionate_T_base.loc[ind, "SpearmanP_base"]

# %%
responder_base.to_csv("responder.Propioniate.base.tsv", sep="\t")
responder_eff.to_csv("responder.Propioniate.eff.tsv", sep="\t")

# %%
plt.figure(figsize=(2, 0.4*len(responder_base.index)))
sns.heatmap(responder_base[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
plt.savefig("heatmap.responder.Propionate.baseline.pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(2, 0.4*len(responder_eff.index)))
sns.heatmap(responder_eff[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
plt.savefig("heatmap.responder.Propionate.eff.pdf", bbox_inches="tight")
plt.show()

# %%
dd = defaultdict(lambda: defaultdict(int))
corr_eff_eff = defaultdict(lambda: defaultdict(int))
eff = pd.concat([ge_eff, ra_eff, nm_eff]).T
for col in eff.columns:
    x = eff[col]
    y = eff["Butyric acid"]
    x = fill_inf(x)
    y = fill_inf(y)
    per, pep = st.pearsonr(x, y)
    spr, spp = st.spearmanr(x, y)
    corr_eff_eff[col]["PearsonR"] = per
    corr_eff_eff[col]["PearsonP"] = pep
    corr_eff_eff[col]["SpearmanR"] = spr
    corr_eff_eff[col]["SpearmanP"] = spp
    dd[col]["PearsonR_eff"] = per
    dd[col]["PearsonP_eff"] = pep
    dd[col]["SpearmanR_eff"] = spr
    dd[col]["SpearmanP_eff"] = spp

responder_eff_T = pd.DataFrame(dd).T

# %%
corr_base_eff = defaultdict(lambda: defaultdict(int))
base = pd.concat([ge_base, ra_base, nm_base]).T
_base = base.copy()
_base.index = [me_T.loc["subject_id", sample_id] for sample_id in _base.index]
for col in _base.columns:
    x = _base.loc[_base.index, col]
    y = eff_all.loc["Butyric acid", _base.index]
    x = fill_inf(x)
    y = fill_inf(y)
    per, pep = st.pearsonr(x, y)
    spr, spp = st.spearmanr(x, y)
    corr_base_eff[col]["PearsonR"] = per
    corr_base_eff[col]["PearsonP"] = pep
    corr_base_eff[col]["SpearmanR"] = spr
    corr_base_eff[col]["SpearmanP"] = spp
    dd[col]["PearsonR_base"] = per
    dd[col]["PearsonP_base"] = pep
    dd[col]["SpearmanR_base"] = spr
    dd[col]["SpearmanP_base"] = spp

responder_base_T = pd.DataFrame(dd).T

# %%
responder_eff = pd.DataFrame(columns=["CF_R", "CF_p", "FG_R", "FG_p"])

for ind in ge_eff.index:
#     if (responder_eff_C.loc[ind, "SpearmanP_eff"] < 0.05) or (responder_eff_T.loc[ind, "SpearmanP_eff"] < 0.05):
    if ((responder_eff_C.loc[ind, "PearsonP_eff"] < 0.1) and (responder_eff_C.loc[ind, "SpearmanP_eff"] < 0.05)) or ((responder_eff_T.loc[ind, "PearsonP_eff"] < 0.1) and (responder_eff_T.loc[ind, "SpearmanP_eff"] < 0.05)):
        responder_eff.loc[ind, "CF_R"] = responder_eff_C.loc[ind, "SpearmanR_eff"]
        responder_eff.loc[ind, "CF_p"] = responder_eff_C.loc[ind, "SpearmanP_eff"]
        responder_eff.loc[ind, "FG_R"] = responder_eff_T.loc[ind, "SpearmanR_eff"]
        responder_eff.loc[ind, "FG_p"] = responder_eff_T.loc[ind, "SpearmanP_eff"]

# %%
responder_base = pd.DataFrame(columns=["CF_R", "CF_p", "FG_R", "FG_p"])

for ind in ge_base.index:
#     if (responder_base_C.loc[ind, "SpearmanP_base"] < 0.05) or (responder_base_T.loc[ind, "SpearmanP_base"] < 0.05):
    if ((responder_base_C.loc[ind, "PearsonP_base"] < 0.1) and (responder_base_C.loc[ind, "SpearmanP_base"] < 0.05)) or ((responder_base_T.loc[ind, "PearsonP_base"] < 0.1) and (responder_base_T.loc[ind, "SpearmanP_base"] < 0.05)):
        responder_base.loc[ind, "CF_R"] = responder_base_C.loc[ind, "SpearmanR_base"]
        responder_base.loc[ind, "CF_p"] = responder_base_C.loc[ind, "SpearmanP_base"]
        responder_base.loc[ind, "FG_R"] = responder_base_T.loc[ind, "SpearmanR_base"]
        responder_base.loc[ind, "FG_p"] = responder_base_T.loc[ind, "SpearmanP_base"]

# %%
responder_base.to_csv("responder.Butyrate.base.tsv", sep="\t")
responder_eff.to_csv("responder.Butyrate.eff.tsv", sep="\t")

# %%
plt.rcParams["font.family"] = "Arial"

# %%
plt.figure(figsize=(2, 0.4*len(responder_base.index)))
sns.heatmap(responder_base[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
plt.savefig("heatmap.responder.Butyrate.baseline.pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(2, 0.4*len(responder_eff.index)))
sns.heatmap(responder_eff[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
plt.savefig("heatmap.responder.Butyrate.eff.pdf", bbox_inches="tight")
plt.show()

# %%
responder_base = pd.DataFrame(columns=["CF_R", "CF_p", "FG_R", "FG_p"])

for ind in eff_all.index:
    if ind == "IgA":
        continue
    if (responder_base_C.loc[ind, "SpearmanP_base"] < 0.05) or (responder_base_T.loc[ind, "SpearmanP_base"] < 0.05):
#     if ((responder_base_C.loc[ind, "PearsonP_base"] < 0.1) and (responder_base_C.loc[ind, "SpearmanP_base"] < 0.05)) or ((responder_base_T.loc[ind, "PearsonP_base"] < 0.1) and (responder_base_T.loc[ind, "SpearmanP_base"] < 0.05)):
        responder_base.loc[ind, "CF_R"] = responder_base_C.loc[ind, "SpearmanR_base"]
        responder_base.loc[ind, "CF_p"] = responder_base_C.loc[ind, "SpearmanP_base"]
        responder_base.loc[ind, "FG_R"] = responder_base_T.loc[ind, "SpearmanR_base"]
        responder_base.loc[ind, "FG_p"] = responder_base_T.loc[ind, "SpearmanP_base"]

# %%
responder_eff = pd.DataFrame(columns=["CF_R", "CF_p", "FG_R", "FG_p"])

for ind in eff_all.index:
    if ind == "IgA":
        continue
    if (responder_eff_C.loc[ind, "SpearmanP_eff"] < 0.05) or (responder_eff_T.loc[ind, "SpearmanP_eff"] < 0.05):
#     if ((responder_eff_C.loc[ind, "PearsonP_eff"] < 0.1) and (responder_eff_C.loc[ind, "SpearmanP_eff"] < 0.05)) or ((responder_eff_T.loc[ind, "PearsonP_eff"] < 0.1) and (responder_eff_T.loc[ind, "SpearmanP_eff"] < 0.05)):
        responder_eff.loc[ind, "CF_R"] = responder_eff_C.loc[ind, "SpearmanR_eff"]
        responder_eff.loc[ind, "CF_p"] = responder_eff_C.loc[ind, "SpearmanP_eff"]
        responder_eff.loc[ind, "FG_R"] = responder_eff_T.loc[ind, "SpearmanR_eff"]
        responder_eff.loc[ind, "FG_p"] = responder_eff_T.loc[ind, "SpearmanP_eff"]

# %%
plt.figure(figsize=(5, .3*len(responder_base.index)))
sns.heatmap(responder_base[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
plt.savefig("heatmap.responder.baseline.sp.pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(5, .3*len(responder_eff.index)))
sns.heatmap(responder_eff[["CF_R", "FG_R"]].astype(float), cmap="coolwarm", vmax=.5, vmin=-.5, annot=True, xticklabels=["CF", "FG"])
plt.savefig("heatmap.responder.eff.sp.pdf", bbox_inches="tight")
plt.show()

# %%
ge_eff_C = pd.read_csv("../data_inter/ge.0.001.C.tsv.eff.IgA.tsv", sep="\t", header=0, index_col=0)
ra_eff_C = pd.read_csv("../data_inter/ra.25.C.tsv.eff.IgA.tsv", sep="\t", header=0, index_col=0)
nm_eff_C = pd.read_csv("../data_inter/nm.all.C.tsv.eff.IgA.tsv", sep="\t", header=0, index_col=0)

ge_eff_T = pd.read_csv("../data_inter/ge.0.001.T.tsv.eff.IgA.tsv", sep="\t", header=0, index_col=0)
ra_eff_T = pd.read_csv("../data_inter/ra.25.T.tsv.eff.IgA.tsv", sep="\t", header=0, index_col=0)
nm_eff_T = pd.read_csv("../data_inter/nm.all.T.tsv.eff.IgA.tsv", sep="\t", header=0, index_col=0)

# %%
x = ra_eff_C.loc["Butyric acid"]
y = nm_eff_C.loc["IgA"]

a, b = np.polyfit(x, y, 1)

X = np.arange(x.min()*1.2, x.max()*1.2, 0.001)
Y = a*X + b

plt.figure(figsize=(4, 4))
# plt.scatter(x, y, c="#A91826")
plt.scatter(x, y, c="#2E7C70")
plt.plot(X, Y, c="gray")
plt.xticks(size=12)
plt.yticks(size=12)
plt.savefig("../data_output/scatter.IgA.Butyrate.C.pdf", bbox_inches="tight")
plt.show()

# %%
x = ra_eff_T.loc["Butyric acid"]
y = nm_eff_T.loc["IgA"]

a, b = np.polyfit(x, y, 1)

X = np.arange(x.min()*1.2, x.max()*1.2, 0.001)
Y = a*X + b

plt.figure(figsize=(4, 4))
plt.scatter(x, y, c="#A91826")
# plt.scatter(x, y, c="#2E7C70")
plt.plot(X, Y, c="gray")
plt.xticks(size=12)
plt.yticks(size=12)
plt.savefig("../data_output/scatter.IgA.Butyrate.T.pdf", bbox_inches="tight")
plt.show()

# %%
x = ra_C.loc["Butyric acid", me_C.loc["timepoint"]=="0w"]
y = nm_eff_C.loc["IgA"]

a, b = np.polyfit(x, y, 1)

X = np.arange(x.min()*1.2, x.max()*1.2, 0.001)
Y = a*X + b

plt.figure(figsize=(4, 4))
# plt.scatter(x, y, c="#A91826")
plt.scatter(x, y, c="#2E7C70")
plt.plot(X, Y, c="gray")
plt.xticks(size=12)
plt.yticks(size=12)
plt.savefig("../data_output/scatter.IgA.Butyrate.baseline.C.pdf", bbox_inches="tight")
plt.show()

# %%
x = ra_T.loc["Butyric acid", me_T.loc["timepoint"]=="0w"]
y = nm_eff_T.loc["IgA"]

a, b = np.polyfit(x, y, 1)

X = np.arange(x.min()*1.2, x.max()*1.2, 0.001)
Y = a*X + b

plt.figure(figsize=(4, 4))
plt.scatter(x, y, c="#A91826")
# plt.scatter(x, y, c="#2E7C70")
plt.plot(X, Y, c="gray")
plt.xticks(size=12)
plt.yticks(size=12)
plt.savefig("../data_output/scatter.IgA.Butyrate.baseline.T.pdf", bbox_inches="tight")
plt.show()

# %%
st.spearmanr(ra_eff_T.loc["Butyric acid"], nm_eff_T.loc["IgA"])
# Out:
# SpearmanrResult(correlation=-0.10227272727272728, pvalue=0.5711578644496516)
